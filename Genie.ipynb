# %% [markdown]
# <a href="https://colab.research.google.com/github/keunsooyoon/crawling/blob/main/Genie.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# pip install selenium

from selenium import webdriver   
# 웹 브라우저 컨트롤

from bs4 import BeautifulSoup as bs
# html

# %%
driver = webdriver.Chrome('chromedriver.exe')
url = 'https://www.genie.co.kr/chart/top200'
driver.get(url)

html = driver.page_source
soup = bs(html, 'html.parser')
soup
# Out:
# <ipython-input-2-3efd7a99c57f>:1: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome('chromedriver.exe')
# <html class="js flexbox canvas canvastext webgl no-touch geolocation postmessage websqldatabase indexeddb hashchange history draganddrop websockets rgba hsla multiplebgs backgroundsize borderimage borderradius boxshadow textshadow opacity cssanimations csscolumns cssgradients cssreflections csstransforms csstransforms3d csstransitions fontface generatedcontent video audio localstorage sessionstorage webworkers no-applicationcache svg inlinesvg smil svgclippaths" dir="ltr" lang="ko" style=""><head>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <!--[if lte IE 6]><html dir="ltr" class="no-js ie6"><![endif]-->
# <!--[if lte IE 7]><html dir="ltr" class="no-js ie7"><![endif]-->
# <!--[if IE 8]><html dir="ltr" class="no-js ie8"><![endif]-->
# <!--[if IE 9]><html dir="ltr" class="no-js ie9"><![endif]-->
# ...

# %%
songs = soup.select('table > tbody > tr')
len(songs)
# Out:
# 50

# %%
song = songs[0]

# %%
title = song.select('a.title')[0].text.strip()
print(title)
# Out:
# 회전목마 (Feat. Zion.T & 원슈타인) (Prod. by Slom)

# %%
singer = song.select('a.artist')
singer
# Out:
# [<a class="artist ellipsis" href="#" onclick="fnViewArtist('80675406');return false;">sokodomo</a>]

# %%
singer = song.select('a.artist')[0].text.strip()
singer
# Out:
# 'sokodomo'

# %%
import pandas as pd

song_data = []
rank = 1

songs = soup.select('table > tbody > tr')

for song in songs:
    title = song.select('a.title')[0].text.strip()
    singer = song.select('a.artist')[0].text.strip()
    song_data.append(['Genie', rank, title, singer])
    rank += 1
    
columns = ['서비스','순위','타이틀','가수']
df = pd.DataFrame(song_data, columns = columns)

df.to_excel('Genie.xlsx', index=False)

# %%
df
# Out:
#       서비스  순위                                                타이틀  \
# 0   Genie   1         회전목마 (Feat. Zion.T & 원슈타인) (Prod. by Slom)
# 1   Genie   2                    쉬어 (Feat. MINO) (Prod. by GRAY)
# 2   Genie   3                          Wake Up (Prod. by 코드 쿤스트)
# 3   Genie   4                                                 문득
# 4   Genie   5                                    strawberry moon
# 5   Genie   6                                             Savage
# 6   Genie   7                                      다정히 내 이름을 부르면
# 7   Genie   8                                          사랑은 늘 도망가
# 8   Genie   9                                                신호등
# 9   Genie  10                                               Stay
# 10  Genie  11                            TROUBLE (Prod. by Slom)
# 11  Genie  12                                     너와 나의 Memories
# 12  Genie  13                                     OHAYO MY NIGHT
# ...

# %%
# Out:
# 11

# %%
# Out:
# [<a class="cover" href="#" onclick="fnViewAlbumLayer('82387392');return false;"><span class="mask"></span><img alt="쇼미더머니 10 Episode 2" onerror="this.src='//image.genie.co.kr/imageg/web/common/blank_68.gif';" src="//image.genie.co.kr/Y/IMAGE/IMG_ALBUM/082/387/392/82387392_1636696960130_1_140x140.JPG/dims/resize/Q_80,0"/></a>,
#  <a class="btn-basic btn-info" href="#" onclick="fnViewSongInfo('94932434');return false;">곡 제목 정보 페이지</a>,
#  <a class="title ellipsis" href="#" onclick="fnPlaySong('94932434','1');return false;" title="재생">
#
#
#
#
#
#
#
#                                                  회전목마 (Feat. Zion.T &amp; 원슈타인) (Prod. by Slom)</a>,
#  <a class="artist ellipsis" href="#" onclick="fnViewArtist('80675406');return false;">sokodomo</a>,
#  <a class="albumtitle ellipsis" href="#" onclick="fnViewAlbumLayer('82387392');return false;">쇼미더머니 10 Episode 2</a>,
#  <a class="btn-basic btn-listen" href="#" onclick="fnPlaySong('94932434;' ,'1'); return false;" title="재생">듣기</a>,
# ...

# %%
title = song.find(class_="title ellipsis").text.strip()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-20-9bf50f9eedba> in <module>
# ----> 1 title = song.find(class_="title ellipsis").text.strip()
#
# ~\anaconda3\lib\site-packages\bs4\element.py in __getattr__(self, key)
#    2171     def __getattr__(self, key):
#    2172         """Raise a helpful exception to explain a common code fix."""
# -> 2173         raise AttributeError(
#    2174             "ResultSet object has no attribute '%s'. You're probably treating a list of elements like a single element. Did you call find_all() when you meant to call find()?" % key
#    2175         )
#
# AttributeError: ResultSet object has no attribute 'find'. You're probably treating a list of elements like a single element. Did you call find_all() when you meant to call find()?
